# %%
#General
include("../sebastien.jl")
using Main.WeirdDetector
using PyPlot
using DataFrames
using CSV

periods = optimal_periods(0.25,15)
# Out:
# 24567-element Array{Float32,1}:
#   0.25
#   0.25004166
#   0.25008333
#   0.25012502
#   0.2501667
#   0.25020844
#   0.25025013
#   0.25029185
#   0.25033355
#   0.25037527
#   0.25041702
#   0.25045875
#   0.2505005
#   ⋮
#  14.972361
#  14.974855
#  14.977355
#  14.979851
#  14.9823475
#  14.984845
#  14.987343
#  14.9898405
#  14.992339
#  14.994838
#  14.997336
#  14.999836

# %%
#150187916
df = loadFITS(0, fitsdir="lcs/", tic_id="150187916", detrend_kw=0.5)
d = pointsify(df)
output=periodogram(d, periods, parallel=true, datakw=true)
output[:delt_chi2] = flatten(periods, output[:chi2], tess=true)
null_output = scrambled_periodogram(df, periods, tess=true)
null_output[:delt_chi2] = flatten(periods, null_output[:chi2], tess=true)
sigma = movingstd((null_output[
    :kurtosis] .- 3) .* (null_output[:delt_chi2]))
    output[:zeta] = (output[:kurtosis] .- 3) .* output[:delt_chi2] ./ sigma

period = periods[findall(a->a==maximum(output[:zeta]), output[:zeta])][1]
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000025BA048>

# %%
period = 0.37196296 * 3
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.7, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000002EBA1940>

# %%
plt.xlim(0.6, 0.8)
scatter(df[:modt], df[:F], alpha=0.8, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000002B40A080>

# %%
#146688260
df = loadFITS(0, fitsdir="lcs/", tic_id="146688260", detrend_kw=0.5)
d = pointsify(df)
output=periodogram(d, periods, parallel=true, datakw=true)
output[:delt_chi2] = flatten(periods, output[:chi2], tess=true)
null_output = scrambled_periodogram(df, periods, tess=true)
null_output[:delt_chi2] = flatten(periods, null_output[:chi2], tess=true)
sigma = movingstd((null_output[
    :kurtosis] .- 3) .* (null_output[:delt_chi2]))
    output[:zeta] = (output[:kurtosis] .- 3) .* output[:delt_chi2] ./ sigma

period = periods[findall(a->a==maximum(output[:zeta]), output[:zeta])][1]
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000032B8A080>

# %%
period = 5.53378772735595 / 11
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000034CAB080>

# %%
plt.xlim(0.25, 0.35)
scatter(df[:modt], df[:F], alpha=0.8, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000034E3ADD8>

# %%
#142148228
df = loadFITS(0, fitsdir="lcs/", tic_id="142148228", detrend_kw=0.5)

period = 1.17062652111053
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000034EC6D30>

# %%
period = 1.17062652111053 / 3
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000360AAA20>

# %%
plt.xlim(0.1, 0.3)
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000036114390>

# %%
#198076334
df = loadFITS(0, fitsdir="lcs/", tic_id="198076334", detrend_kw=0.5)

period = 1.17394804954528
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000371F50B8>

# %%
period = 1.17394804954528 / 3
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000372469B0>

# %%
plt.xlim(0.25, 0.33)
scatter(df[:modt], df[:F], alpha=0.6, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000037368CF8>

# %%
#220474209
df = loadFITS(0, fitsdir="lcs/", tic_id="220474209", detrend_kw=0.5)

period = 13.7225341796875
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000015EA1DD8>

# %%
period = 13.7225341796875 / 14
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000015E598D0>

# %%
plt.xlim(0.15, 0.25)
scatter(df[:modt], df[:F], alpha=0.6, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000016087668>

# %%
#299135660
df = loadFITS(0, fitsdir="lcs/", tic_id="299135660", detrend_kw=0.5)

period = 2.88456058502197
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000160C5CC0>

# %%
plt.xlim(2.3, 2.7)
scatter(df[:modt], df[:F], alpha=0.6, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000016345780>

# %%
#364302118
# df = loadFITS(0, fitsdir="lcs/", tic_id="364302118", detrend_kw=0.5)

period = 14.7986993789672 / 22
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000039DF3E48>

# %%
plt.xlim(.55, .7)
scatter(df[:modt], df[:F], alpha=0.6, s=0.2)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000003AEE72E8>
