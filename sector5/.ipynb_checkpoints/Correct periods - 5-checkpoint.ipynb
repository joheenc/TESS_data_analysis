# %%
#General
include("../sebastien.jl")
using Main.WeirdDetector
using PyPlot
using DataFrames

# %%
#146597035
df = loadFITS(0, fitsdir="lcs/", tic_id="146597035", detrend_kw=0.5)

period = 1.10006844997406
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000000211C748>

# %%
period = 1.10006844997406 * 2
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000000243E048>

# %%
plt.xlim(.4, .55)
scatter(df[:modt], df[:F], alpha=0.6, s=0.2)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x00000000024ED710>

# %%
#150187916
df = loadFITS(0, fitsdir="lcs/", tic_id="150187916", detrend_kw=0.5)

period = 1.11632168292999
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000002553128>

# %%
plt.xlim(.1, .19)
scatter(df[:modt], df[:F], alpha=0.8, s=0.2)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000002FF24160>

# %%
#178996712
df = loadFITS(0, fitsdir="lcs/", tic_id="178996712", detrend_kw=0.5)

period = 2.98283004760742
df[:modt] = df[:t] .% period
scatter(df[:modt], df[:F], alpha=0.4, s=0.1)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000003109B710>

# %%
plt.xlim(2.65, 2.85)
scatter(df[:modt], df[:F], alpha=0.8, s=0.3)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000031332048>
