# %%
using CSV

# %%
isfile("D:/Users/Joheen/Documents/Research/sector1.csv")
# Out:
# false

# %%
data = CSV.read("D:/Users/Joheen/Documents/Research/sector1.csv")
print(data)
# Out:
# ArgumentError: "D:/Users/Joheen/Documents/Research/sector1.csv" is not a valid file
#
# Stacktrace:
#  [1] #Source#24(::String, ::CSV.Options{Void}, ::Int64, ::Int64, ::Array{Type,1}, ::Symbol, ::Void, ::Bool, ::Void, ::Symbol, ::Int64, ::Int64, ::Int64, ::Bool, ::Type{T} where T) at C:\Users\Joheen\.julia\v0.6\CSV\src\Source.jl:59
#  [2] (::Core.#kw#Type)(::Array{Any,1}, ::Type{CSV.Source}) at .\<missing>:0
#  [3] #Source#23(::UInt8, ::UInt8, ::UInt8, ::String, ::Void, ::Int64, ::Int64, ::Array{Type,1}, ::Symbol, ::Void, ::Void, ::UInt8, ::String, ::String, ::Bool, ::Void, ::Symbol, ::Int64, ::Int64, ::Int64, ::Bool, ::Type{T} where T, ::String) at C:\Users\Joheen\.julia\v0.6\CSV\src\Source.jl:31
#  [4] #read#43(::Bool, ::Dict{Int64,Function}, ::Bool, ::Array{Any,1}, ::Function, ::String, ::Type{T} where T) at C:\Users\Joheen\.julia\v0.6\CSV\src\Source.jl:347
#  [5] read(::String) at C:\Users\Joheen\.julia\v0.6\CSV\src\Source.jl:347
# ...

# %%
logzeta = Float32[]
for x in data[:Peak_Zeta]
    push!(logzeta, log(10, x))
end
data[:logzeta] = logzeta
print(data)
# Out:
# UndefVarError: data not defined
#
# Stacktrace:
#  [1] anonymous at .\<missing>:?
#  [2] include_string(::String, ::String) at .\loading.jl:522

# %%
using PyPlot
figure(figsize=(4, 3))
scatter(log.(data[:Guessed_Period]), data[:logzeta], alpha=0.8, s=0.3)

#Make a histogram
#Plot log period v log zeta
#Mark TOIs with red dots
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000004780D30>
